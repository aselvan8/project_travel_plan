# %%
import csv
import pandas as pd

# %%
# reading the CSV file 
csvFile = pd.read_csv("../data/travel_data.csv") 
  
# displaying the contents of the CSV file 
print(csvFile)
# Out:
#        Unnamed: 0         date  state_fips state_code  pop_stay_at_home  \
# 0               0  01-Jan-2019           1         AL           1028578
# 1               1  01-Jan-2019          33         NH            312645
# 2               2  01-Jan-2019          34         NJ           2244189
# 3               3  01-Jan-2019          35         NM            525761
# 4               4  01-Jan-2019          36         NY           5931873
# ...           ...          ...         ...        ...               ...
# 31045       31666  12-Sep-2020          13         GA           2531945
# 31046       31667  12-Sep-2020          36         NY           6579119
# 31047       31668  12-Sep-2020          44         RI            290914
# 31048       31669  12-Sep-2020           8         CO           1663763
# 31049       31670  12-Sep-2020          45         SC           1156132
#
#        pop_not_stay_at_home     trips   trips_1  trips_1_3  trips_3_5  ...  \
# ...

# %%
data = csvFile
data = data.drop(['Unnamed: 0'],axis=1)
data
# Out:
#               date  state_fips state_code  pop_stay_at_home  \
# 0      01-Jan-2019           1         AL           1028578
# 1      01-Jan-2019          33         NH            312645
# 2      01-Jan-2019          34         NJ           2244189
# 3      01-Jan-2019          35         NM            525761
# 4      01-Jan-2019          36         NY           5931873
# ...            ...         ...        ...               ...
# 31045  12-Sep-2020          13         GA           2531945
# 31046  12-Sep-2020          36         NY           6579119
# 31047  12-Sep-2020          44         RI            290914
# 31048  12-Sep-2020           8         CO           1663763
# 31049  12-Sep-2020          45         SC           1156132
#
#        pop_not_stay_at_home     trips   trips_1  trips_1_3  trips_3_5  \
# 0                   3844356  11968328   2792091    3151108    1604875
# 1                   1039666   3705345    726417     970009     492350
# ...

# %%
data.to_html
data
# Out:
#               date  state_fips state_code  pop_stay_at_home  \
# 0      01-Jan-2019           1         AL           1028578
# 1      01-Jan-2019          33         NH            312645
# 2      01-Jan-2019          34         NJ           2244189
# 3      01-Jan-2019          35         NM            525761
# 4      01-Jan-2019          36         NY           5931873
# ...            ...         ...        ...               ...
# 31045  12-Sep-2020          13         GA           2531945
# 31046  12-Sep-2020          36         NY           6579119
# 31047  12-Sep-2020          44         RI            290914
# 31048  12-Sep-2020           8         CO           1663763
# 31049  12-Sep-2020          45         SC           1156132
#
#        pop_not_stay_at_home     trips   trips_1  trips_1_3  trips_3_5  \
# 0                   3844356  11968328   2792091    3151108    1604875
# 1                   1039666   3705345    726417     970009     492350
# ...

# %%
data.to_html(open('../templates/travel_table.html', 'w'))
